# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/himu30/Machine_learning_with_python/blob/master/assignment_19.ipynb)

# %% [markdown]
# # Assignment - 19  K Means Clustering

# %% [markdown]
# ***K means on MNIST dataset***

# %% [markdown]
# **Importing MNIST data set from sklearn**

# %% [markdown]
# **Q-1.)**

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
digit = load_digits()

# %%
#storing targets and digit values in y and x respectively
x = digit.data
print(x)

y = digit.target
print(y)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]

# %% [markdown]
# **Q-2.)**

# %%
from sklearn.cluster import KMeans
k_mn = KMeans(n_clusters = 10 , random_state = 0, init ='k-means++')

#Computing clusters centers and cluster index for each
pred_val = k_mn.fit_predict(x)
pred_val
# Out:
# array([5, 7, 7, ..., 7, 3, 3], dtype=int32)

# %% [markdown]
# **Q-3.)**

# %%
label = np.zeros_like(y)
print(label)
label.shape
# Out:
# [0 0 0 ... 0 0 0]
# (1797,)

# %%
# Now use of mode function to save the most common variables
from scipy.stats import mode

for i in range(len(label)):
  label[i] = mode(y[i])[0]

# %% [markdown]
# **Q-4.) Accuracy and confusion Matrix**

# %%
#Accuarcy_score 
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(val , label)
# Out:
# 0.015581524763494713

# %%
#confusion matrix
confusion_matrix(val ,label)
# Out:
# array([[  1,   0,   0,   0, 163,   2,   0,   0,   0,   0],
#        [  0,   1,  13, 154,   0,   0,   0,   0,   2,   6],
#        [  0,   1,   0,   2,   0, 136,   0,   0,   4,   6],
#        [  0,   0,   2,  13,   0,  43,   0,   0,  53, 139],
#        [  0,   0,   3,   7,   7,   0,   0, 177,   5,   7],
#        [177,   0,   1,   0,   0,   0,   1,   0,   0,   0],
#        [  0,  55,   2,   0,   7,   0,   1,   0,   5,  20],
#        [  0,  99,   8,   7,   4,   0,   2,   2, 100,   2],
#        [  0,  24, 148,   0,   0,   0,   0,   0,   3,   0],
#        [  0,   2,   0,   0,   0,   1, 177,   0,   2,   0]])

# %% [markdown]
# ***Image dataset***

# %% [markdown]
# Q-1.)

# %%
#loading Image
from sklearn.datasets import load_sample_image
img = load_sample_image("flower.jpg")

# %%
 plt.imshow(img)

# %% [markdown]
#                          Flower image

# %% [markdown]
# **q-2.)**

# %%
#shape of image
img.shape
# Out:
# (427, 640, 3)

# %% [markdown]
# **Q-3.)**

# %%
#Shape of the image
img.shape
img_1 = img

# %%
img_2=img_1.reshape(427*640,3)

# %%
img_2.shape
# Out:
# (273280, 3)

# %% [markdown]
# **Q-4.)**

# %%
img_1 = KMeans(n_clusters = 7 , init ='k-means++')
print(img_1)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
f_img = img_1.fit_predict(img_2)

# %%
f_img.shape
# Out:
# (273280,)
